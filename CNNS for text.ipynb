# %%
# https://www.kaggle.com/shivamkushwaha/bbc-full-text-document-classification
# !wget -nc https://lazyprogrammer.me/course_files/nlp/bbc_text_cls.csv
# Out:
# --2023-08-17 02:07:02--  https://lazyprogrammer.me/course_files/nlp/bbc_text_cls.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 172.67.213.166, 104.21.23.210, 2606:4700:3031::6815:17d2, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|172.67.213.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5085081 (4.8M) [text/csv]
# Saving to: ‘bbc_text_cls.csv’
#
# bbc_text_cls.csv    100%[===================>]   4.85M  5.78MB/s    in 0.8s
#
# 2023-08-17 02:07:03 (5.78 MB/s) - ‘bbc_text_cls.csv’ saved [5085081/5085081]

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Input, GlobalMaxPooling1D
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Embedding
from tensorflow.keras.models import Model
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %%
df = pd.read_csv('bbc_text_cls.csv')
df.head()
# Out:
#                                                 text    labels
# 0  Ad sales boost Time Warner profit\n\nQuarterly...  business
# 1  Dollar gains on Greenspan speech\n\nThe dollar...  business
# 2  Yukos unit buyer faces loan claim\n\nThe owner...  business
# 3  High fuel prices hit BA's profits\n\nBritish A...  business
# 4  Pernod takeover talk lifts Domecq\n\nShares in...  business

# %%
df['targets'] = df['labels'].astype("category").cat.codes

# %%
# number of classes
K = df['targets'].max() + 1
K
# Out:
# 5

# %%
df_train, df_test = train_test_split(df, test_size=0.3)

# %%
# Convert sentences to sequences
MAX_VOCAB_SIZE = 2000
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE)
tokenizer.fit_on_texts(df_train['text'])
sequences_train = tokenizer.texts_to_sequences(df_train['text'])
sequences_test = tokenizer.texts_to_sequences(df_test['text'])

# %%
# get word -> integer mapping
word2idx = tokenizer.word_index
V = len(word2idx)
print('Found %s unique tokens.' % V)
# Out:
# Found 27700 unique tokens.

# %%
# pad sequences so that we get a N x T matrix
data_train = pad_sequences(sequences_train)
print('Shape of data train tensor:', data_train.shape)

# get sequence length
T = data_train.shape[1]
# Out:
# Shape of data train tensor: (1557, 3469)

# %%
data_test = pad_sequences(sequences_test, maxlen=T)
print('Shape of data test tensor:', data_test.shape)
# Out:
# Shape of data test tensor: (668, 3469)

# %%
# Create the model

# We get to choose embedding dimensionality
D = 50

# Note: we actually want to the size of the embedding to (V + 1) x D,
# because the first index starts from 1 and not 0.
# Thus, if the final index of the embedding matrix is V,
# then it actually must have size V + 1.

i = Input(shape=(T,))
x = Embedding(V + 1, D)(i)
x = Conv1D(32, 3, activation='relu')(x)
# x = MaxPooling1D(3)(x)
# x = Conv1D(64, 3, activation='relu')(x)
# x = MaxPooling1D(3)(x)
# x = Conv1D(128, 3, activation='relu')(x)
x = GlobalMaxPooling1D()(x)
x = Dense(K)(x)

model = Model(i, x)

# %%
# Compile and fit
model.compile(
  loss=SparseCategoricalCrossentropy(from_logits=True),
  optimizer='adam',
  metrics=['accuracy']
)


print('Training model...')
r = model.fit(
  data_train,
  df_train['targets'],
  epochs=50,
  validation_data=(data_test, df_test['targets'])
)
# Out:
# Training model...
# Epoch 1/50
# 49/49 [==============================] - 18s 334ms/step - loss: 1.5632 - accuracy: 0.3455 - val_loss: 1.5046 - val_accuracy: 0.4117
# Epoch 2/50
# 49/49 [==============================] - 13s 265ms/step - loss: 1.3441 - accuracy: 0.6718 - val_loss: 1.2022 - val_accuracy: 0.7889
# Epoch 3/50
# 49/49 [==============================] - 12s 240ms/step - loss: 0.9107 - accuracy: 0.8921 - val_loss: 0.7331 - val_accuracy: 0.8922
# Epoch 4/50
# 49/49 [==============================] - 11s 235ms/step - loss: 0.4854 - accuracy: 0.9351 - val_loss: 0.4228 - val_accuracy: 0.9207
# Epoch 5/50
# 49/49 [==============================] - 12s 243ms/step - loss: 0.2728 - accuracy: 0.9550 - val_loss: 0.2959 - val_accuracy: 0.9296
# Epoch 6/50
# 49/49 [==============================] - 10s 213ms/step - loss: 0.1757 - accuracy: 0.9698 - val_loss: 0.2337 - val_accuracy: 0.9401
# Epoch 7/50
# 49/49 [==============================] - 12s 233ms/step - loss: 0.1213 - accuracy: 0.9769 - val_loss: 0.2020 - val_accuracy: 0.9446
# Epoch 8/50
# 49/49 [==============================] - 12s 249ms/step - loss: 0.0878 - accuracy: 0.9878 - val_loss: 0.1782 - val_accuracy: 0.9476
# Epoch 9/50
# 49/49 [==============================] - 12s 243ms/step - loss: 0.0636 - accuracy: 0.9942 - val_loss: 0.1651 - val_accuracy: 0.9521
# Epoch 10/50
# 49/49 [==============================] - 13s 264ms/step - loss: 0.0478 - accuracy: 0.9961 - val_loss: 0.1529 - val_accuracy: 0.9566
# Epoch 11/50
# 49/49 [==============================] - 12s 244ms/step - loss: 0.0364 - accuracy: 0.9981 - val_loss: 0.1459 - val_accuracy: 0.9581
# Epoch 12/50
# 49/49 [==============================] - 12s 243ms/step - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9611
# Epoch 13/50
# 49/49 [==============================] - 12s 243ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9596
# Epoch 14/50
# 49/49 [==============================] - 12s 242ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9596
# Epoch 15/50
# 49/49 [==============================] - 12s 243ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9611
# Epoch 16/50
# 49/49 [==============================] - 12s 246ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.1297 - val_accuracy: 0.9626
# Epoch 17/50
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.1285 - val_accuracy: 0.9626
# Epoch 18/50
# 49/49 [==============================] - 11s 227ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9641
# Epoch 19/50
# 49/49 [==============================] - 12s 242ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9626
# Epoch 20/50
# 49/49 [==============================] - 12s 242ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1257 - val_accuracy: 0.9626
# Epoch 21/50
# 49/49 [==============================] - 12s 248ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9626
# Epoch 22/50
# 49/49 [==============================] - 12s 236ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9656
# Epoch 23/50
# 49/49 [==============================] - 12s 243ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9656
# Epoch 24/50
# 49/49 [==============================] - 12s 242ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9656
# Epoch 25/50
# 49/49 [==============================] - 12s 251ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9656
# Epoch 26/50
# 49/49 [==============================] - 11s 224ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9656
# Epoch 27/50
# 49/49 [==============================] - 12s 243ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9656
# Epoch 28/50
# 49/49 [==============================] - 12s 242ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9656
# Epoch 29/50
# 49/49 [==============================] - 11s 233ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9656
# Epoch 30/50
# 49/49 [==============================] - 12s 243ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9656
# Epoch 31/50
# 49/49 [==============================] - 12s 240ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9656
# Epoch 32/50
# 49/49 [==============================] - 12s 242ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9656
# Epoch 33/50
# 49/49 [==============================] - 11s 233ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9656
# Epoch 34/50
# 49/49 [==============================] - 12s 241ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9656
# Epoch 35/50
# 49/49 [==============================] - 10s 205ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9656
# Epoch 36/50
# 49/49 [==============================] - 11s 228ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9656
# Epoch 37/50
# 49/49 [==============================] - 12s 241ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9656
# Epoch 38/50
# 49/49 [==============================] - 12s 235ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9656
# Epoch 39/50
# 49/49 [==============================] - 12s 242ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9656
# Epoch 40/50
# 49/49 [==============================] - 12s 242ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9656
# Epoch 41/50
# 49/49 [==============================] - 12s 241ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9656
# Epoch 42/50
# 49/49 [==============================] - 12s 250ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9656
# Epoch 43/50
# 49/49 [==============================] - 11s 222ms/step - loss: 9.4941e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9656
# Epoch 44/50
# 49/49 [==============================] - 11s 228ms/step - loss: 8.9554e-04 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9656
# Epoch 45/50
# 49/49 [==============================] - 12s 237ms/step - loss: 8.4684e-04 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9656
# Epoch 46/50
# 49/49 [==============================] - 12s 238ms/step - loss: 7.9951e-04 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9656
# Epoch 47/50
# 49/49 [==============================] - 11s 232ms/step - loss: 7.5562e-04 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9656
# Epoch 48/50
# 49/49 [==============================] - 11s 229ms/step - loss: 7.1636e-04 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9656
# Epoch 49/50
# 49/49 [==============================] - 11s 226ms/step - loss: 6.7911e-04 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9656
# Epoch 50/50
# 49/49 [==============================] - 11s 223ms/step - loss: 6.4374e-04 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9656

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend();

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend();
