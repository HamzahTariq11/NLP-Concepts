# %%
# https://www.kaggle.com/crowdflower/twitter-airline-sentiment
# !wget -nc https://lazyprogrammer.me/course_files/AirlineTweets.csv
# Out:
# File ‘AirlineTweets.csv’ already there; not retrieving.

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
np.random.seed(0)
tf.random.set_seed(0)

# %%
df = pd.read_csv('AirlineTweets.csv')

# %%
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
df = df[['airline_sentiment', 'text']]

# %%
df['airline_sentiment'].hist()
# Out:
# <Axes: >

# %%
df = df[df['airline_sentiment'] != 'neutral'].copy()

# %%
target_map = {'positive': 1, 'negative': 0}
df['target'] = df['airline_sentiment'].map(target_map)

# %%
df.head()
# Out:
#   airline_sentiment                                               text  target
# 1          positive  @VirginAmerica plus you've added commercials t...       1
# 3          negative  @VirginAmerica it's really aggressive to blast...       0
# 4          negative  @VirginAmerica and it's a really big bad thing...       0
# 5          negative  @VirginAmerica seriously would pay $30 a fligh...       0
# 6          positive  @VirginAmerica yes, nearly every time I fly VX...       1

# %%
df_train, df_test = train_test_split(df, random_state=42)

# %%
vectorizer = TfidfVectorizer(max_features=2000)
X_train = vectorizer.fit_transform(df_train['text'])
X_test = vectorizer.transform(df_test['text'])

# %%
# data must not be sparse matrix before passing into tensorflow
X_train = X_train.toarray()
X_test = X_test.toarray()

# %%
Y_train = df_train['target']
Y_test = df_test['target']

# %%
# input dimensions
D = X_train.shape[1]

# %%
# build model
i = Input(shape=(D,))
x = Dense(1)(i) # sigmoid included in loss

model = Model(i, x)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2000)]            0
#
#  dense (Dense)               (None, 1)                 2001
#
# =================================================================
# Total params: 2,001
# Trainable params: 2,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
  loss=BinaryCrossentropy(from_logits=True),
  optimizer=Adam(learning_rate=0.01),
  metrics=['accuracy']
)

# %%
r = model.fit(
  X_train, Y_train,
  validation_data=(X_test, Y_test),
  epochs=40,
  batch_size=128,
)
# Out:
# Epoch 1/40
# 68/68 [==============================] - 2s 9ms/step - loss: 0.5033 - accuracy: 0.7920 - val_loss: 0.3967 - val_accuracy: 0.8049
# Epoch 2/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.3754 - accuracy: 0.7968 - val_loss: 0.3388 - val_accuracy: 0.8205
# Epoch 3/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.3219 - accuracy: 0.8196 - val_loss: 0.3023 - val_accuracy: 0.8416
# Epoch 4/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.2848 - accuracy: 0.8451 - val_loss: 0.2765 - val_accuracy: 0.8607
# Epoch 5/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.2574 - accuracy: 0.8642 - val_loss: 0.2579 - val_accuracy: 0.8777
# Epoch 6/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.2365 - accuracy: 0.8812 - val_loss: 0.2441 - val_accuracy: 0.8888
# Epoch 7/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.2201 - accuracy: 0.8925 - val_loss: 0.2334 - val_accuracy: 0.9002
# Epoch 8/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.2066 - accuracy: 0.9027 - val_loss: 0.2245 - val_accuracy: 0.9040
# Epoch 9/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1955 - accuracy: 0.9096 - val_loss: 0.2178 - val_accuracy: 0.9092
# Epoch 10/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1859 - accuracy: 0.9153 - val_loss: 0.2123 - val_accuracy: 0.9106
# Epoch 11/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1776 - accuracy: 0.9198 - val_loss: 0.2078 - val_accuracy: 0.9130
# Epoch 12/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1705 - accuracy: 0.9242 - val_loss: 0.2041 - val_accuracy: 0.9144
# Epoch 13/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1641 - accuracy: 0.9266 - val_loss: 0.2012 - val_accuracy: 0.9186
# Epoch 14/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1584 - accuracy: 0.9309 - val_loss: 0.1985 - val_accuracy: 0.9186
# Epoch 15/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1533 - accuracy: 0.9337 - val_loss: 0.1964 - val_accuracy: 0.9196
# Epoch 16/40
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1485 - accuracy: 0.9356 - val_loss: 0.1946 - val_accuracy: 0.9210
# Epoch 17/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1443 - accuracy: 0.9384 - val_loss: 0.1932 - val_accuracy: 0.9213
# Epoch 18/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1404 - accuracy: 0.9419 - val_loss: 0.1918 - val_accuracy: 0.9217
# Epoch 19/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1367 - accuracy: 0.9427 - val_loss: 0.1907 - val_accuracy: 0.9217
# Epoch 20/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1334 - accuracy: 0.9433 - val_loss: 0.1900 - val_accuracy: 0.9217
# Epoch 21/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1303 - accuracy: 0.9444 - val_loss: 0.1892 - val_accuracy: 0.9220
# Epoch 22/40
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1274 - accuracy: 0.9465 - val_loss: 0.1889 - val_accuracy: 0.9224
# Epoch 23/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1246 - accuracy: 0.9480 - val_loss: 0.1885 - val_accuracy: 0.9231
# Epoch 24/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1220 - accuracy: 0.9509 - val_loss: 0.1883 - val_accuracy: 0.9224
# Epoch 25/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1196 - accuracy: 0.9497 - val_loss: 0.1881 - val_accuracy: 0.9241
# Epoch 26/40
# 68/68 [==============================] - 1s 7ms/step - loss: 0.1174 - accuracy: 0.9527 - val_loss: 0.1881 - val_accuracy: 0.9238
# Epoch 27/40
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1152 - accuracy: 0.9545 - val_loss: 0.1882 - val_accuracy: 0.9248
# Epoch 28/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1130 - accuracy: 0.9533 - val_loss: 0.1883 - val_accuracy: 0.9255
# Epoch 29/40
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1110 - accuracy: 0.9564 - val_loss: 0.1885 - val_accuracy: 0.9252
# Epoch 30/40
# 68/68 [==============================] - 0s 7ms/step - loss: 0.1092 - accuracy: 0.9552 - val_loss: 0.1886 - val_accuracy: 0.9255
# Epoch 31/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1074 - accuracy: 0.9570 - val_loss: 0.1890 - val_accuracy: 0.9255
# Epoch 32/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1058 - accuracy: 0.9584 - val_loss: 0.1895 - val_accuracy: 0.9248
# Epoch 33/40
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1041 - accuracy: 0.9596 - val_loss: 0.1898 - val_accuracy: 0.9245
# Epoch 34/40
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1025 - accuracy: 0.9601 - val_loss: 0.1903 - val_accuracy: 0.9241
# Epoch 35/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1010 - accuracy: 0.9600 - val_loss: 0.1908 - val_accuracy: 0.9238
# Epoch 36/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0996 - accuracy: 0.9620 - val_loss: 0.1914 - val_accuracy: 0.9234
# Epoch 37/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0982 - accuracy: 0.9623 - val_loss: 0.1921 - val_accuracy: 0.9227
# Epoch 38/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0968 - accuracy: 0.9634 - val_loss: 0.1926 - val_accuracy: 0.9231
# Epoch 39/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0955 - accuracy: 0.9634 - val_loss: 0.1931 - val_accuracy: 0.9217
# Epoch 40/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0943 - accuracy: 0.9650 - val_loss: 0.1940 - val_accuracy: 0.9227

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend();

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend();

# %%
P_train = ((model.predict(X_train) > 0) * 1.0).flatten()
P_test = ((model.predict(X_test) > 0) * 1.0).flatten()
# Out:
# 271/271 [==============================] - 0s 1ms/step
# 91/91 [==============================] - 0s 1ms/step

# %%
cm = confusion_matrix(Y_train, P_train, normalize='true')
cm
# Out:
# array([[0.99110139, 0.00889861],
#        [0.09888889, 0.90111111]])

# %%
# Scikit-Learn is transitioning to V1 but it's not available on Colab
# The changes modify how confusion matrices are plotted
def plot_cm(cm):
  classes = ['negative', 'positive']
  df_cm = pd.DataFrame(cm, index=classes, columns=classes)
  ax = sn.heatmap(df_cm, annot=True, fmt='g')
  ax.set_xlabel("Predicted")
  ax.set_ylabel("Target")

plot_cm(cm)

# %%
cm_test = confusion_matrix(Y_test, P_test, normalize='true')
plot_cm(cm_test)

# %%
Pr_train = model.predict(X_train)
Pr_test = model.predict(X_test)
print("Train AUC:", roc_auc_score(Y_train, Pr_train))
print("Test AUC:", roc_auc_score(Y_test, Pr_test))
# Out:
# 271/271 [==============================] - 1s 3ms/step
# 91/91 [==============================] - 0s 4ms/step
# Train AUC: 0.9950035659291676
# Test AUC: 0.9547516571102628

# %%
print("Train F1:", f1_score(Y_train, P_train))
print("Test F1:", f1_score(Y_test, P_test))
# Out:
# Train F1: 0.9313809933964974
# Test F1: 0.7935909519321396

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7d3c41a67ac0>,
#  <keras.layers.core.dense.Dense at 0x7d3c41a679a0>]

# %%
model.layers[1].get_weights()
# Out:
# [array([[-3.681547 ],
#         [ 3.2988346],
#         [-1.5746452],
#         ...,
#         [ 2.065721 ],
#         [ 1.64045  ],
#         [-2.8923655]], dtype=float32),
#  array([-0.24942441], dtype=float32)]

# %%
w = model.layers[1].get_weights()[0]

# %%
word_index_map = vectorizer.vocabulary_
word_index_map
# Out:
# {'jetblue': 973,
#  'thanks': 1726,
#  'for': 753,
#  'having': 855,
#  'us': 1859,
#  'hang': 838,
#  'out': 1262,
#  'at': 197,
#  'tampa': 1708,
#  'airport': 122,
#  'forever': 756,
#  'today': 1767,
#  'it': 964,
#  'really': 1420,
#  'been': 243,
#  'an': 147,
#  'awesome': 217,
#  'experience': 654,
#  'americanair': 143,
#  'was': 1898,
#  'told': 1770,
#  'you': 1993,
#  'could': 452,
#  'only': 1245,
#  'refund': 1434,
#  'me': 1107,
#  'the': 1730,
#  'cost': 448,
#  'of': 1224,
#  'my': 1179,
#  'original': 1254,
#  'return': 1476,
#  'flight': 726,
#  'note': 1211,
#  'had': 828,
#  'booked': 273,
#  'more': 1164,
#  'expensive': 653,
#  'everyone': 635,
#  'else': 602,
#  'outstanding': 1267,
#  'united': 1842,
#  'denver': 516,
#  'to': 1766,
#  'austin': 207,
#  'still': 1660,
#  'on': 1239,
#  'ground': 820,
#  'issue': 961,
#  'is': 959,
#  'lack': 999,
#  'announcement': 151,
#  'made': 1086,
#  'so': 1606,
#  'late': 1010,
#  'when': 1929,
#  'gate': 793,
#  'agent': 113,
#  'there': 1734,
#  'over': 1268,
#  'hour': 897,
#  'southwestair': 1626,
#  'hold': 880,
#  '30': 36,
#  'min': 1141,
#  'trying': 1808,
#  'rebook': 1423,
#  'cancelled': 314,
#  'flightled': 734,
#  'help': 867,
#  'from': 773,
#  'phl': 1309,
#  'dal': 485,
#  'rebooked': 1424,
#  'tomorrow': 1771,
#  'now': 1217,
#  'that': 1728,
#  'again': 111,
#  'usairways': 1861,
#  'phone': 1312,
#  'called': 308,
#  'number': 1218,
#  'and': 148,
#  'she': 1560,
#  'picked': 1317,
#  'up': 1850,
#  'almost': 131,
#  'immediately': 926,
#  'just': 980,
#  'sent': 1545,
#  'another': 154,
#  'drink': 579,
#  'think': 1739,
#  'have': 853,
#  'free': 765,
#  'drinks': 580,
#  'anyone': 161,
#  'guys': 826,
#  'off': 1225,
#  'if': 921,
#  'every': 634,
#  'employees': 609,
#  'would': 1971,
#  'making': 1093,
#  'effort': 600,
#  'credit': 467,
#  'where': 1930,
#  'due': 586,
#  'delayed': 507,
#  'hours': 898,
#  'instead': 951,
#  've': 1873,
#  '55': 58,
#  'mins': 1145,
#  'about': 78,
#  'flighted': 730,
#  'international': 953,
#  'am': 139,
#  'country': 458,
#  'can': 313,
#  'leave': 1016,
#  'call': 306,
#  'back': 221,
#  'got': 816,
#  'worked': 1959,
#  'trip': 1800,
#  'pay': 1294,
#  'extra': 664,
#  'though': 1746,
#  'not': 1209,
#  'easy': 597,
#  'poor': 1349,
#  'did': 537,
#  'report': 1452,
#  'updated': 1852,
#  'info': 945,
#  'don': 571,
#  'know': 993,
#  'how': 901,
#  'reach': 1414,
#  'them': 1732,
#  'without': 1949,
#  'super': 1681,
#  'long': 1058,
#  'wait': 1886,
#  'your': 1995,
#  'main': 1088,
#  'use': 1863,
#  'voucher': 1884,
#  'book': 272,
#  'last': 1009,
#  'lines': 1041,
#  'are': 175,
#  'busy': 297,
#  'may': 1103,
#  'go': 808,
#  'wife': 1939,
#  'flt': 742,
#  'via': 1876,
#  'dfw': 534,
#  'bought': 279,
#  'swa': 1691,
#  'get': 798,
#  'her': 871,
#  'home': 883,
#  'dm': 561,
#  'plz': 1342,
#  'course': 460,
#  'but': 298,
#  'they': 1736,
#  'were': 1921,
#  'as': 185,
#  'why': 1937,
#  'getting': 800,
#  'put': 1397,
#  'by': 302,
#  'people': 1300,
#  'calling': 309,
#  'platinum': 1333,
#  'desk': 528,
#  'thankfully': 1725,
#  'lounge': 1070,
#  'next': 1196,
#  'door': 574,
#  'impressed': 929,
#  'thank': 1724,
#  'with': 1947,
#  'passbook': 1284,
#  'all': 126,
#  'works': 1962,
#  'much': 1175,
#  'better': 251,
#  'happening': 843,
#  'delta': 513,
#  'took': 1774,
#  'care': 322,
#  'purchase': 1394,
#  'ticket': 1754,
#  'check': 359,
#  'in': 932,
#  'bag': 225,
#  'however': 902,
#  'being': 246,
#  'charged': 352,
#  '25': 29,
#  'dollars': 569,
#  'domestic': 570,
#  'heard': 862,
#  'charge': 351,
#  '1st': 19,
#  'seats': 1530,
#  'no': 1202,
#  'need': 1188,
#  'be': 238,
#  'loyal': 1078,
#  'jb': 971,
#  'customer': 478,
#  'anymore': 160,
#  'already': 134,
#  'spoke': 1637,
#  'line': 1040,
#  'support': 1683,
#  'wasn': 1899,
#  'delay': 506,
#  'engine': 613,
#  'needed': 1189,
#  'makes': 1092,
#  'person': 1305,
#  'stand': 1643,
#  'pilot': 1319,
#  'or': 1251,
#  'paperwork': 1279,
#  'fix': 720,
#  'problem': 1376,
#  'fixed': 721,
#  'ago': 115,
#  'set': 1552,
#  'days': 493,
#  'hoping': 890,
#  'won': 1951,
#  'filled': 707,
#  'because': 241,
#  'link': 1042,
#  'doesn': 565,
#  'work': 1958,
#  'amp': 146,
#  'asked': 189,
#  'many': 1098,
#  'questions': 1402,
#  'might': 1135,
#  'should': 1566,
#  'seattle': 1531,
#  'strand': 1667,
#  'someone': 1614,
#  'city': 372,
#  'luggage': 1083,
#  'aa': 74,
#  'want': 1894,
#  'earn': 593,
#  'business': 296,
#  'guess': 823,
#  'needs': 1190,
#  'their': 1731,
#  'shit': 1561,
#  'together': 1769,
#  'counter': 456,
#  'catch': 330,
#  'flights': 737,
#  'http': 905,
#  'co': 388,
#  'passengers': 1287,
#  'sitting': 1586,
#  'plane': 1326,
#  'two': 1820,
#  'cmh': 386,
#  'other': 1258,
#  'left': 1019,
#  'usairwaysfail': 1862,
#  'hrs': 904,
#  'months': 1163,
#  'supposed': 1685,
#  'mom': 1157,
#  'whose': 1936,
#  'very': 1875,
#  'upset': 1857,
#  'crews': 469,
#  'surprised': 1688,
#  'arrive': 180,
#  'fuck': 779,
#  'this': 1742,
#  'will': 1941,
#  'never': 1191,
#  'bad': 222,
#  'weather': 1910,
#  'multiple': 1176,
#  'has': 848,
#  'time': 1759,
#  'reservation': 1464,
#  'cant': 318,
#  'through': 1749,
#  'woman': 1950,
#  'who': 1933,
#  'working': 1961,
#  'find': 710,
#  'tonight': 1772,
#  'exec': 647,
#  'online': 1244,
#  'clear': 378,
#  'amazing': 140,
#  'officially': 1230,
#  'favorite': 689,
#  'airline': 119,
#  'day': 492,
#  'like': 1037,
#  'waited': 1887,
#  'bags': 227,
#  'coming': 399,
#  'ahead': 116,
#  'live': 1047,
#  'premium': 1365,
#  'route': 1490,
#  'lhr': 1031,
#  'well': 1919,
#  'didn': 538,
#  'then': 1733,
#  'airplane': 121,
#  'worst': 1968,
#  'fly': 743,
#  'ever': 633,
#  'train': 1785,
#  'attendants': 203,
#  'monday': 1160,
#  're': 1413,
#  'haven': 854,
#  'any': 159,
#  'idea': 919,
#  'what': 1925,
#  '200': 21,
#  'couldn': 453,
#  'even': 630,
#  'give': 802,
#  'food': 752,
#  'comp': 404,
#  'take': 1700,
#  'stranded': 1668,
#  'flying': 747,
#  'new': 1193,
#  'we': 1909,
#  'stuck': 1669,
#  'rather': 1411,
#  'than': 1723,
#  'broken': 285,
#  'charlotte': 356,
#  'service': 1550,
#  'agents': 114,
#  'kind': 990,
#  'way': 1907,
#  'hopefully': 889,
#  'future': 789,
#  'different': 542,
#  'procedure': 1378,
#  'car': 320,
#  'seat': 1527,
#  'lost': 1067,
#  'reimburse': 1440,
#  'one': 1242,
#  'child': 367,
#  'baggage': 226,
#  'handlers': 835,
#  'totally': 1777,
#  'our': 1261,
#  'barely': 230,
#  'run': 1502,
#  'connect': 431,
#  'den': 514,
#  'came': 311,
#  'mail': 1087,
#  'early': 592,
#  'bird': 258,
#  'great': 819,
#  'first': 716,
#  'crew': 468,
#  'takes': 1703,
#  'overhead': 1270,
#  'bin': 256,
#  'space': 1627,
#  'paying': 1295,
#  'customers': 479,
#  'annoyed': 152,
#  'stay': 1655,
#  'please': 1336,
#  'which': 1931,
#  'name': 1182,
#  'tag': 1699,
#  '11': 6,
#  'planes': 1327,
#  '50': 55,
#  'its': 968,
#  '10': 2,
#  '20': 20,
#  'tarmac': 1709,
#  'going': 811,
#  'compensate': 408,
#  'companion': 405,
#  'pass': 1283,
#  'ridiculous': 1482,
#  'hadn': 829,
#  'stopped': 1663,
#  'hotels': 896,
#  'non': 1204,
#  'solve': 1610,
#  'miss': 1151,
#  'funeral': 786,
#  'suck': 1674,
#  'newark': 1194,
#  'checked': 360,
#  'under': 1833,
#  'too': 1773,
#  'happy': 845,
#  'enter': 617,
#  'hey': 873,
#  'remember': 1445,
#  'do': 563,
#  'email': 603,
#  'gotten': 818,
#  'yet': 1990,
#  'delays': 509,
#  'little': 1046,
#  'communication': 403,
#  'goes': 810,
#  'nice': 1198,
#  'routes': 1491,
#  'jet': 972,
#  'blue': 265,
#  'southwest': 1625,
#  'least': 1015,
#  'treat': 1796,
#  'properly': 1387,
#  'heads': 860,
#  'arrived': 181,
#  'those': 1745,
#  'aren': 177,
#  'claim': 373,
#  'point': 1344,
#  'gt': 822,
#  'after': 109,
#  'planned': 1328,
#  'departure': 521,
#  'california': 305,
#  'here': 872,
#  'originally': 1255,
#  'keeping': 983,
#  'safe': 1507,
#  'sister': 1583,
#  'reply': 1450,
#  'ur': 1858,
#  'services': 1551,
#  '18': 15,
#  'response': 1473,
#  'lousy': 1071,
#  'unitedairlines': 1843,
#  'following': 751,
#  'ice': 915,
#  'front': 774,
#  'landed': 1004,
#  'information': 946,
#  'saw': 1517,
#  'helpful': 869,
#  'specific': 1631,
#  'cs': 473,
#  'look': 1060,
#  'apologize': 167,
#  'trouble': 1802,
#  'buffalo': 291,
#  'jfk': 975,
#  'figured': 703,
#  'anything': 162,
#  'make': 1091,
#  'll': 1049,
#  'excuses': 646,
#  'hi': 874,
#  'im': 923,
#  'speak': 1628,
#  'travel': 1790,
#  'minor': 1144,
#  'keeps': 984,
#  'advise': 106,
#  'website': 1912,
#  'wont': 1955,
#  'allow': 128,
#  'thx': 1753,
#  'social': 1607,
#  'media': 1114,
#  'memphis': 1120,
#  'something': 1615,
#  'also': 135,
#  'useless': 1866,
#  'canned': 316,
#  '1k': 18,
#  'let': 1025,
#  'kids': 988,
#  'board': 268,
#  'wish': 1946,
#  'team': 1712,
#  'member': 1118,
#  'pick': 1316,
#  'alone': 132,
#  'clt': 383,
#  'gonna': 814,
#  'connection': 434,
#  'ua': 1824,
#  'change': 345,
#  'music': 1177,
#  'leaving': 1018,
#  'morning': 1165,
#  'auto': 208,
#  'tuesday': 1810,
#  'night': 1199,
#  'horrendous': 891,
#  'flown': 741,
#  'come': 396,
#  'pathetic': 1290,
#  'waiting': 1888,
#  'yesterday': 1989,
#  'class': 374,
#  'passenger': 1286,
#  'win': 1943,
#  'lt': 1080,
#  'mind': 1142,
#  'states': 1653,
#  'maintenance': 1089,
#  'app': 169,
#  'says': 1520,
#  'arriving': 183,
#  'aircraft': 118,
#  'tell': 1715,
#  'unfriendly': 1838,
#  'right': 1483,
#  'whole': 1935,
#  'form': 758,
#  'before': 244,
#  'direct': 545,
#  'address': 101,
#  'plans': 1330,
#  'system': 1697,
#  'reflight': 1433,
#  'booking': 274,
#  'problems': 1377,
#  'disconnect': 553,
#  'between': 252,
#  'face': 669,
#  'enough': 616,
#  'miles': 1138,
#  'enjoy': 615,
#  'perfect': 1302,
#  'coffee': 392,
#  'tracking': 1783,
#  'tells': 1717,
#  'nothing': 1213,
#  'less': 1023,
#  'easily': 595,
#  'company': 406,
#  'experienced': 655,
#  'personal': 1306,
#  'caused': 333,
#  'ruining': 1500,
#  'ashamed': 187,
#  'gave': 795,
#  'wrong': 1975,
#  'nothappy': 1212,
#  'vouchers': 1885,
#  'runway': 1504,
#  'saturday': 1515,
#  'bwi': 301,
#  'appreciate': 172,
#  'power': 1358,
#  'laptop': 1006,
#  'iphone': 958,
#  'missing': 1153,
#  'good': 815,
#  'holder': 881,
#  'conditions': 422,
#  'arrival': 179,
#  'de': 496,
#  'icing': 916,
#  'three': 1748,
#  'far': 682,
#  'sure': 1686,
#  'taking': 1704,
#  '15': 11,
#  '12': 7,
#  '40': 48,
#  '45': 51,
#  'minutes': 1148,
#  'jetway': 974,
#  'hotel': 895,
#  '32': 41,
#  'counting': 457,
#  'gotta': 817,
#  'record': 1430,
#  'air': 117,
#  'delivered': 511,
#  'destination': 530,
#  'frequent': 767,
#  'traveler': 1792,
#  'treated': 1797,
#  'offer': 1226,
#  'pls': 1340,
#  'start': 1647,
#  'luv': 1084,
#  'ya': 1979,
#  'finally': 709,
#  'nashville': 1183,
#  'answers': 158,
#  'away': 216,
#  'chicago': 365,
#  'drove': 585,
#  'prepared': 1366,
#  'bringing': 283,
#  'does': 564,
#  'sense': 1544,
#  'yay': 1981,
#  'nuts': 1220,
#  'cold': 393,
#  'eventually': 632,
#  'explained': 659,
#  'virginamerica': 1881,
#  'understanding': 1835,
#  'helped': 868,
#  'best': 250,
#  'lady': 1000,
#  'advance': 104,
#  '24': 27,
#  'prior': 1372,
#  'tried': 1799,
#  'earlier': 591,
#  'wanted': 1895,
#  '300': 37,
#  'fees': 696,
#  'sfo': 1555,
#  'say': 1518,
#  'consistent': 438,
#  'high': 875,
#  'quality': 1400,
#  'keep': 982,
#  'quick': 1404,
#  'serious': 1546,
#  'question': 1401,
#  'showing': 1571,
#  'place': 1323,
#  'fyi': 790,
#  'dropped': 584,
#  'able': 77,
#  'conf': 423,
#  'appreciated': 173,
#  'suppose': 1684,
#  'til': 1757,
#  'glad': 806,
#  'damaged': 488,
#  'answer': 155,
#  'hung': 911,
#  'disappointed': 549,
#  'losing': 1065,
#  'fill': 706,
#  'soon': 1618,
#  'land': 1003,
#  'hope': 888,
#  'feedback': 693,
#  'virgin': 1880,
#  'went': 1920,
#  'smooth': 1601,
#  'ride': 1481,
#  'wow': 1973,
#  'thinking': 1740,
#  'same': 1512,
#  'ps': 1391,
#  'overnight': 1271,
#  'meet': 1115,
#  'either': 601,
#  'connections': 435,
#  'tx': 1821,
#  'see': 1535,
#  'year': 1984,
#  'love': 1072,
#  'consider': 436,
#  'fare': 683,
#  'price': 1369,
#  'try': 1807,
#  'father': 687,
#  'loved': 1074,
#  'likely': 1038,
#  'slow': 1598,
#  'internet': 954,
#  'addressed': 102,
#  'fee': 692,
#  'yes': 1988,
#  'cust': 477,
#  'svc': 1689,
#  'said': 1510,
#  'evening': 631,
#  'further': 788,
#  'both': 277,
#  'during': 588,
#  'broke': 284,
#  'open': 1247,
#  'camera': 312,
#  'read': 1416,
#  'believe': 247,
#  'incident': 934,
#  'fault': 688,
#  'sw': 1690,
#  'done': 572,
#  'ive': 969,
#  'boarding': 270,
#  'catering': 331,
#  'always': 138,
#  'nightmare': 1200,
#  'fail': 671,
#  'kidding': 987,
#  'talked': 1706,
#  'human': 908,
#  'asking': 190,
#  'follow': 749,
#  'vacation': 1870,
#  'finish': 714,
#  'some': 1611,
#  'text': 1722,
#  'carrier': 325,
#  'card': 321,
#  'nope': 1207,
#  'apparently': 170,
#  'times': 1761,
#  'wtf': 1977,
#  'looks': 1063,
#  'handling': 836,
#  'connecting': 433,
#  'thru': 1751,
#  'impossible': 928,
#  'actually': 96,
#  'final': 708,
#  'attitude': 205,
#  'these': 1735,
#  'mco': 1105,
#  'iad': 913,
#  'fingers': 713,
#  'crossed': 471,
#  'four': 762,
#  'meeting': 1116,
#  'atlanta': 199,
#  'slept': 1597,
#  'security': 1534,
#  'onto': 1246,
#  'crying': 472,
#  'baby': 220,
#  'situation': 1587,
#  'drop': 583,
#  'incredibly': 941,
#  'unacceptable': 1829,
#  'issues': 963,
#  'based': 231,
#  'things': 1738,
#  'control': 444,
#  'wifi': 1940,
#  'tv': 1814,
#  'double': 576,
#  'comment': 400,
#  'anywhere': 164,
#  'south': 1624,
#  'florida': 740,
#  'gone': 813,
#  'hello': 866,
#  'forgot': 757,
#  'thought': 1747,
#  'mosaic': 1166,
#  'perks': 1304,
#  'part': 1281,
#  'checking': 362,
#  '60': 62,
#  'upgrade': 1854,
#  'solution': 1609,
#  'show': 1569,
#  'track': 1782,
#  'disappeared': 548,
#  'dulles': 587,
#  'lax': 1011,
#  'thursday': 1752,
#  'honest': 884,
#  'reschedule': 1461,
#  'btw': 289,
#  'intl': 955,
#  'flightd': 729,
#  'area': 176,
#  'pretty': 1367,
#  'probably': 1375,
#  'plus': 1341,
#  'hearing': 863,
#  'overbooked': 1269,
#  'since': 1580,
#  'file': 704,
#  'cool': 445,
#  'pre': 1361,
#  'thing': 1737,
#  'single': 1582,
#  'philly': 1308,
#  'deal': 498,
#  'boarded': 269,
#  'joke': 978,
#  'computer': 417,
#  'ing': 948,
#  'complain': 411,
#  'public': 1392,
#  'afternoon': 110,
#  'six': 1588,
#  'layover': 1012,
#  'party': 1282,
#  'assist': 193,
#  'except': 643,
#  'message': 1125,
#  'trust': 1806,
#  'bna': 267,
#  'rdu': 1412,
#  'most': 1167,
#  'excellent': 642,
#  'fa': 666,
#  'such': 1673,
#  'warm': 1897,
#  'onboard': 1240,
#  'welcome': 1918,
#  'wonder': 1952,
#  'hate': 851,
#  'dealing': 499,
#  'airlines': 120,
#  'policies': 1347,
#  'resolution': 1466,
#  'jan': 970,
#  'options': 1250,
#  'returning': 1478,
#  'hanging': 839,
#  'mistake': 1154,
#  'replying': 1451,
#  'feel': 694,
#  'requested': 1457,
#  'reward': 1479,
#  'points': 1345,
#  'used': 1864,
#  'he': 856,
#  'refused': 1438,
#  'screwed': 1525,
#  'big': 254,
#  '1hr': 17,
#  '2nd': 34,
#  'wouldn': 1972,
#  'view': 1879,
#  'changes': 347,
#  'outside': 1265,
#  'flightr': 736,
#  'acceptable': 84,
#  'entire': 619,
#  'dca': 495,
#  'nobody': 1203,
#  'knows': 996,
#  'pm': 1343,
#  'job': 977,
#  'angry': 149,
#  'kudos': 997,
#  'fast': 685,
#  'congrats': 430,
#  'systems': 1698,
#  'down': 577,
#  'plan': 1325,
#  'american': 142,
#  'cuz': 482,
#  'behind': 245,
#  'schedule': 1521,
#  'staff': 1642,
#  'cabin': 304,
#  'bos': 275,
#  'ogg': 1232,
#  'using': 1867,
#  'hard': 846,
#  'given': 803,
#  'legs': 1022,
#  'confirm': 425,
#  'informed': 947,
#  'flightlation': 732,
#  'letter': 1027,
#  'sna': 1602,
#  'causes': 334,
#  'provide': 1388,
#  'transportation': 1789,
#  'wedding': 1913,
#  'watch': 1903,
#  '3hrs': 45,
#  'sju': 1591,
#  'worse': 1967,
#  'handle': 833,
#  'hangs': 840,
#  'wall': 1892,
#  'middle': 1133,
#  'mad': 1085,
#  'unhelpful': 1841,
#  'rude': 1498,
#  '2hrs': 33,
#  'beyond': 253,
#  'spiritairlines': 1636,
#  'receive': 1426,
#  'assistance': 194,
#  'apology': 168,
#  'disappointing': 550,
#  'airways': 124,
#  'answering': 157,
#  'ugh': 1826,
#  'ok': 1234,
#  'insane': 949,
#  'request': 1456,
#  'completely': 415,
#  'paid': 1275,
#  'group': 821,
#  'doing': 568,
#  'while': 1932,
#  'isn': 960,
#  'supervisor': 1682,
#  'regarding': 1439,
#  'travels': 1795,
#  'stuff': 1670,
#  'carry': 327,
#  'spent': 1635,
#  'account': 89,
#  'houston': 900,
#  'express': 661,
#  '35': 42,
#  'additional': 100,
#  'delivery': 512,
#  'crazy': 466,
#  'update': 1851,
#  'infant': 943,
#  'children': 368,
#  'nyc': 1222,
#  'unbelievable': 1831,
#  'inbound': 933,
#  'equipment': 622,
#  'moving': 1171,
#  'happens': 844,
#  'often': 1231,
#  'la': 998,
#  'gives': 804,
#  'absolute': 80,
#  'found': 761,
#  'straight': 1666,
#  'talk': 1705,
#  'rescheduled': 1462,
#  'okay': 1235,
#  'large': 1007,
#  'real': 1418,
#  'god': 809,
#  'tiny': 1762,
#  'man': 1094,
#  'past': 1289,
#  'assignment': 192,
#  'chairman': 343,
#  'preferred': 1363,
#  'row': 1493,
#  'employee': 608,
#  'telling': 1716,
#  'fit': 717,
#  'clearly': 379,
#  'fits': 718,
#  'nah': 1181,
#  'dont': 573,
#  'humans': 909,
#  'respond': 1470,
#  'relations': 1444,
#  'midnight': 1134,
#  'cheers': 363,
#  'mean': 1109,
#  'posted': 1357,
#  'usair': 1860,
#  '800': 71,
#  'calls': 310,
#  'contact': 439,
#  'understand': 1834,
#  'missed': 1152,
#  'mechanical': 1112,
#  'failure': 674,
#  'lose': 1064,
#  '400': 49,
#  'mon': 1159,
#  'status': 1654,
#  'match': 1101,
#  'program': 1381,
#  'weeks': 1917,
#  'emailed': 604,
#  'inside': 950,
#  'money': 1161,
#  'phones': 1313,
#  'suggestions': 1677,
#  '48': 52,
#  'frustrated': 776,
#  'items': 966,
#  'embarrassing': 606,
#  ...}

# %%
# let's look at the weights for each word
# try it with different threshold values!
threshold = 2

print("Most positive words:")
word_weight_tuples = []
for word, index in word_index_map.items():
    weight = w[index, 0]
    if weight > threshold:
        word_weight_tuples.append((word, weight))

word_weight_tuples = sorted(word_weight_tuples, key=lambda x: -x[1])
for i in range(10):
  word, weight = word_weight_tuples[i]
  print(word, weight)
# Out:
# Most positive words:
# thank 9.706938
# thanks 9.408182
# worries 8.435082
# great 7.925287
# awesome 7.4009285
# love 7.2844586
# excellent 7.089539
# kudos 6.6819406
# amazing 6.4760346
# best 6.135672

# %%
print("Most negative words:")
word_weight_tuples = []
for word, index in word_index_map.items():
    weight = w[index, 0]
    if weight < -threshold:
        word_weight_tuples.append((word, weight))

word_weight_tuples = sorted(word_weight_tuples, key=lambda x: x[1])
for i in range(10):
  word, weight = word_weight_tuples[i]
  print(word, weight)
# Out:
# Most negative words:
# worst -9.295753
# paid -7.743149
# not -7.652519
# rude -7.5322137
# disappointed -7.2063966
# website -6.8299017
# nothing -6.80437
# hung -6.6675925
# instead -6.549873
# list -6.2725086
