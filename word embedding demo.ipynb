# %%
# !wget -nc https://lazyprogrammer.me/course_files/nlp/GoogleNews-vectors-negative300.bin.gz
# Out:
# --2023-07-20 01:05:22--  https://lazyprogrammer.me/course_files/nlp/GoogleNews-vectors-negative300.bin.gz
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 172.67.213.166, 104.21.23.210, 2606:4700:3030::ac43:d5a6, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|172.67.213.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1647046227 (1.5G) [application/x-gzip]
# Saving to: ‘GoogleNews-vectors-negative300.bin.gz’
#
# GoogleNews-vectors- 100%[===================>]   1.53G  40.4MB/s    in 38s
#
# 2023-07-20 01:06:00 (41.8 MB/s) - ‘GoogleNews-vectors-negative300.bin.gz’ saved [1647046227/1647046227]

# %%
import gdown

# %%
# You are better off just downloading this from the source
# https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit?usp=sharing
# https://code.google.com/archive/p/word2vec/

#using pre-trained word embeddings as it is very costly to train algos like transformers etc.
# !gdown https://drive.google.com/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM
# To: /content/GoogleNews-vectors-negative300.bin.gz
# 100% 1.65G/1.65G [00:19<00:00, 84.8MB/s]

# %%
# !gunzip GoogleNews-vectors-negative300.bin.gz  #unzipping

# %%
from gensim.models import KeyedVectors

# %%
word_vectors= KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin',binary=True)

# %%
def find_analogies(w1,w2,w3):
  # king- man= ? - women
  r=word_vectors.most_similar(positive=[w1,w3],negative=[w2])
  print("%s - %s = %s - %s" % (w1,w2,r[0][0],w3))

# %%
find_analogies('king','man','woman')
# Out:
# king - man = queen - woman

# %%
find_analogies('france','paris','london')
# Out:
# france - paris = england - london

# %%
find_analogies('einstein','scientist','artist')
# Out:
# einstein - scientist = jude - artist

# %%
find_analogies('france','french','english')
# Out:
# france - french = england - english

# %%
find_analogies('man','women','actress')
# Out:
# man - women = actor - actress

# %%
def nearest_neighbor(w):
  r= word_vectors.most_similar(positive=[w])
  print('neighbors: %s'%w)
  for word,score in r:
    print('\t%s'%word)

# %%
nearest_neighbor('king')
# Out:
# neighbors: king
# 	kings
# 	queen
# 	monarch
# 	crown_prince
# 	prince
# 	sultan
# 	ruler
# 	princes
# 	Prince_Paras
# 	throne

# %%
nearest_neighbor('japan')
# Out:
# neighbors: japan
# 	japanese
# 	tokyo
# 	america
# 	europe
# 	germany
# 	chinese
# 	india
# 	hawaii
# 	usa
# 	korea

# %%
nearest_neighbor('movies')
# Out:
# neighbors: movies
# 	films
# 	movie
# 	flicks
# 	film
# 	Hollywood_blockbusters
# 	Movies
# 	horror_flicks
# 	blockbusters
# 	indie_flicks
# 	romcoms

# %%
nearest_neighbor('comedy')
# Out:
# neighbors: comedy
# 	comedies
# 	comedic
# 	sitcom
# 	sketch_comedy
# 	dramedy
# 	Comedy
# 	romantic_comedy
# 	comic
# 	sitcoms
# 	satire

# %%
nearest_neighbor('einstein')
# Out:
# neighbors: einstein
# 	nikki
# 	lmfao
# 	albert
# 	armstrong
# 	joan
# 	becky
# 	mcmahon
# 	conrad
# 	lori
# 	haley

# %%
nearest_neighbor('december')
# Out:
# neighbors: december
# 	september
# 	april
# 	october
# 	february
# 	july
# 	november
# 	january
# 	june
# 	feb
# 	microsoft
